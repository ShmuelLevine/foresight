# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("EURGBP-2016-1hr.pp.dat", header=None)

# %%
dif = data[:-1] - data[:1]

# %%
dif = data[0].diff()
dif.hist().plot()
# Out:
# []

# %%
data.plot.hist()

# %%
df = pd.DataFrame(dif)

# %%
df.plot.hist(bins=20, logy=True)
